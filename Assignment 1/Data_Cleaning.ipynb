# %%
# Assignment No:1
# Name: Jalindranath Kangane
# Roll No.: 27
# Batch  : T2
# Title  :  Python Data Cleaning With pandas and NumPy Performing Data Analysis Using Python

# %%
# import the library
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Europe Sales Records.csv")
df.head()
# Out:
#    Region                 Country        Item Type Sales Channel  \
# 0  Europe          Czech Republic        Beverages       Offline
# 1  Europe  Bosnia and Herzegovina          Clothes        Online
# 2  Europe                 Austria           Cereal       Offline
# 3  Europe                Bulgaria  Office Supplies        Online
# 4  Europe                 Estonia           Fruits        Online
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              C   9/12/2011  478051030   9/29/2011        4778       47.45
# 1              M  10/14/2013  919133651   11/4/2013         927      109.28
# 2              C   8/13/2014  987410676    9/6/2014        5616      205.70
# 3              L  10/31/2010  672330081  11/29/2010        6266      651.21
# 4              L   9/28/2016  579463422   11/1/2016        4958        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      31.79      226716.10   151892.62      74823.48
# ...

# %%
df.head(10)
# Out:
#    Region                 Country        Item Type Sales Channel  \
# 0  Europe          Czech Republic        Beverages       Offline
# 1  Europe  Bosnia and Herzegovina          Clothes        Online
# 2  Europe                 Austria           Cereal       Offline
# 3  Europe                Bulgaria  Office Supplies        Online
# 4  Europe                 Estonia           Fruits        Online
# 5  Europe              Montenegro           Fruits       Offline
# 6  Europe          Czech Republic           Cereal        Online
# 7  Europe              Luxembourg       Vegetables       Offline
# 8  Europe             Switzerland             Meat        Online
# 9  Europe                 Finland        Beverages        Online
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              C   9/12/2011  478051030   9/29/2011        4778       47.45
# 1              M  10/14/2013  919133651   11/4/2013         927      109.28
# ...

# %%
df["Order ID"].is_unique
# Out:
# True

# %%
df = df.set_index("Order ID")

# %%
df.head(10)
# Out:
#            Region                 Country        Item Type Sales Channel  \
# Order ID
# 478051030  Europe          Czech Republic        Beverages       Offline
# 919133651  Europe  Bosnia and Herzegovina          Clothes        Online
# 987410676  Europe                 Austria           Cereal       Offline
# 672330081  Europe                Bulgaria  Office Supplies        Online
# 579463422  Europe                 Estonia           Fruits        Online
# 313705861  Europe              Montenegro           Fruits       Offline
# 552037513  Europe          Czech Republic           Cereal        Online
# 744683635  Europe              Luxembourg       Vegetables       Offline
# 169378983  Europe             Switzerland             Meat        Online
# 566428315  Europe                 Finland        Beverages        Online
#
#           Order Priority  Order Date   Ship Date  Units Sold  Unit Price  \
# Order ID
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     7
# float64    5
# int64      1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1330 entries, 478051030 to 906794202
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1330 non-null   object
#  1   Country         1330 non-null   object
#  2   Item Type       1330 non-null   object
#  3   Sales Channel   1330 non-null   object
#  4   Order Priority  1330 non-null   object
#  5   Order Date      1330 non-null   object
#  6   Ship Date       1330 non-null   object
#  7   Units Sold      1330 non-null   int64
#  8   Unit Price      1330 non-null   float64
#  9   Unit Cost       1330 non-null   float64
#  10  Total Revenue   1330 non-null   float64
#  11  Total Cost      1330 non-null   float64
#  12  Total Profit    1330 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 145.5+ KB

# %%
to_drop = ['V5',
            'V12',
            'V15']
df.drop(to_drop, inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 4
#       1 to_drop = ['V5',
#       2             'V12',
#       3             'V15']
# ----> 4 df.drop(to_drop, inplace=True, axis=1)
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
df.head()
# Out:
#               V1        V2        V3        V4        V6        V7        V8  \
# Amount
# 149.62 -1.359807 -0.072781  2.536347  1.378155  0.462388  0.239599  0.098698
# 2.69    1.191857  0.266151  0.166480  0.448154 -0.082361 -0.078803  0.085102
# 378.66 -1.358354 -1.340163  1.773209  0.379780  1.800499  0.791461  0.247676
# 123.50 -0.966272 -0.185226  1.792993 -0.863291  1.247203  0.237609  0.377436
# 69.99  -1.158233  0.877737  1.548718  0.403034  0.095921  0.592941 -0.270533
#
#               V9       V10       V11  ...       V20       V21       V22  \
# Amount                                ...
# 149.62  0.363787  0.090794 -0.551600  ...  0.251412 -0.018307  0.277838
# 2.69   -0.255425 -0.166974  1.612727  ... -0.069083 -0.225775 -0.638672
# 378.66 -1.514654  0.207643  0.624501  ...  0.524980  0.247998  0.771679
# 123.50 -1.387024 -0.054952 -0.226487  ... -0.208038 -0.108300  0.005274
# 69.99   0.817739  0.753074 -0.822843  ...  0.408542 -0.009431  0.798278
#
# ...

# %%
new_column  = {"Region": "Area"}
temp = df.rename(columns=new_column)

# %%
temp.head()
# Out:
#            Region                 Country        Item Type Sales Channel  \
# Order ID
# 478051030  Europe          Czech Republic        Beverages       Offline
# 919133651  Europe  Bosnia and Herzegovina          Clothes        Online
# 987410676  Europe                 Austria           Cereal       Offline
# 672330081  Europe                Bulgaria  Office Supplies        Online
# 579463422  Europe                 Estonia           Fruits        Online
#
#           Order Priority  Order Date   Ship Date  Units Sold  Unit Price  \
# Order ID
# 478051030              C   9/12/2011   9/29/2011        4778       47.45
# 919133651              M  10/14/2013   11/4/2013         927      109.28
# 987410676              C   8/13/2014    9/6/2014        5616      205.70
# 672330081              L  10/31/2010  11/29/2010        6266      651.21
# 579463422              L   9/28/2016   11/1/2016        4958        9.33
#
#            Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
print("Number of columns in df:", len(df.columns))
# Out:
# Number of columns in df: 26

# %%
print("End")
# Out:
# End
